# %% [markdown]
# NWOYE KAMSIYOCHUKWU;MAT. NO:
# 21120612477
# kamsiyochukwu.nwoye@pau.edu.ng

# %% [markdown]
# PROJECT1

# %% [markdown]
# PICTORIAL REPRESENTATION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# INPUT number(n):
# PROCESS n-17:
# If n>17,
# COMPUTE is 2n.
# ELSE n<17.
# PRINT n.

# %%
def diff():
    n = int(input("input number: "))
    if n<=17:
        print(n-17)
    else:
        print(2*n)
        return
diff()
# Out:
# input number: 22
# 44

# %% [markdown]
# PROJECT 2

# %% [markdown]
# PICTORIAL REPRESENTATION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = float(input("input first number: "))
b = float(input("input second number: "))
c = float(input("input third number: "))
add = a + b + c
if a == b == c:
    print(3*add)
else:
    print(add)
# Out:
# input first number: 2
# input second number: 2
# input third number: 2
# 18.0

# %% [markdown]
# THE ALGORITHM:
#     INPUT three numbers(n1,n2,n3)
#     IF the numbers are the same
#     COMPUTE, SUM n1,n2 and n3
#     SUM*3
#     ELSE PRINT SUM

# %% [markdown]
# PROJECT 3

# %% [markdown]
# PICTORIAL REPRESENTATION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ALGORITHIM:
# INPUT numbers for a and b.
# IF a = b,
# ELIF a+b=5
# ELIF a-d=5
# PRINT TRUE
# ELSE
# PRINT FALSE

# %%
def com():
    a = float(input("input first number: "))
    b = float(input("input second number: "))
    if a==b:
        print(True)
    elif a + b == 5:
        print(True)
    elif a - b == 5:
        print(True)
    else:
        print(False)
        return
com()
# Out:
# input first number: 10
# input second number: 5
# True

# %% [markdown]
# PROJECT 4

# %% [markdown]
# PICTORIAL REPRESENTATION:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = float(input('input first number: '))
y = float(input('input second number: '))
z = float(input('input third number: '))
a1 = max(x,y,z)
a2 = min(x,y,z)
a3 = (x + y + z) - a1 - a2
print('numbers in sort order: ',a2,a3,a1)
# Out:
# input first number: 2
# input second number: 5
# input third number: 8
# numbers in sort order:  2.0 5.0 8.0

# %% [markdown]
# INPUT maximum number(a)
# INPUT minumum number(b)
# INPUT middle number(c)
# SUM a,b and c(e)
# SUBTRACT a and b from e
